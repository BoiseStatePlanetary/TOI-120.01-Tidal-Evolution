# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "toi120.forward"

data = np.genfromtxt(filename, names=('time', 'semi', 'ecc', 'period'))

plt.plot(data['time'], data['semi'])
